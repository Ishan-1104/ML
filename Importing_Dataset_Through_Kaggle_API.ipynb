# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan-1104/ML/blob/main/Importing_Dataset_Through_Kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing the Kaggle library
# !pip install kaggle

# %% [markdown]
# Upload Kaggle.json File

# %%
import os
os.environ["KAGGLE_API_TOKEN"] = "KGAT_f545fc566b1651482b8cb07ce8637c85"

# %%
# !mkdir -p ~/.kaggle
# !echo $KAGGLE_API_TOKEN > ~/.kaggle/access_token
# !chmod 600 ~/.kaggle/access_token

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                                title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# laveshjadon/ai-impact-on-students                                  Impact of Ai on Students                               1187170  2026-05-10 23:12:10.070000          13198        314                1
# mmumairkhattak/e-commerce-orders-dataset-2026-scra                 E-commerce Orders Dataset 2026 | SCRA                  1796478  2026-06-11 06:56:56.550000           1220         27        0.9411765
# ...

# %% [markdown]
# Importing EarthQuake Dataset

# %%
#API to fetch the dataset from Kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
# 100% 2.27G/2.27G [00:37<00:00, 65.9MB/s]

# %%
# !ls /content
# Out:
# LANL-Earthquake-Prediction.zip	sample_data

# %%
# !ls -lh
# Out:
# total 2.3G
# -rw-r--r-- 1 root root 2.3G Dec 18  2019 LANL-Earthquake-Prediction.zip
# drwxr-xr-x 1 root root 4.0K Jun  4 13:32 sample_data

# %%
from zipfile import ZipFile

with ZipFile('/content/LANL-Earthquake-Prediction.zip', 'r') as zip_ref:
    zip_ref.extractall('/content')

print("Main ZIP extracted successfully!")
# Out:
# Main ZIP extracted successfully!

# %%
# !ls -lh /content
# Out:
# total 12G
# -rw-r--r-- 1 root root 2.3G Dec 18  2019 LANL-Earthquake-Prediction.zip
# drwxr-xr-x 1 root root 4.0K Jun  4 13:32 sample_data
# -rw-r--r-- 1 root root  34K Jun 18 10:56 sample_submission.csv
# drwxr-xr-x 2 root root  92K Jun 18 10:56 test
# -rw-r--r-- 1 root root 8.9G Jun 18 10:58 train.csv

# %%
import pandas as pd

df = pd.read_csv('/content/train.csv', nrows=1000000)

# %%
df.head()
# Out:
#    acoustic_data  time_to_failure
# 0             12           1.4691
# 1              6           1.4691
# 2              8           1.4691
# 3              5           1.4691
# 4              8           1.4691

# %%
df.shape
# Out:
# (1000000, 2)
